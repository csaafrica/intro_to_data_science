# %%
# %autosave
# Out:
# UsageError: %autosave requires an integer, got ''

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
bike_data = pd.read_csv("../data/bikes.csv")

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
bike_data.describe()
# Out:
#        real_temperature  feel_temperature    humidity  wind_speed  \
# count        730.000000        657.000000  730.000000  730.000000
# mean          12.481849         11.506088   73.034932   15.954665
# std            5.086471          6.110233   10.245519    6.221691
# min            0.250000         -2.000000   40.500000    2.770833
# 25%            8.812500          6.250000   65.250000   11.208333
# 50%           12.625000         12.500000   73.750000   15.166667
# 75%           16.187500         16.000000   80.750000   19.906250
# max           28.500000         29.000000  100.000000   41.900000
#
#               count
# count    730.000000
# mean   27268.454795
# std     8607.700254
# min     4869.000000
# 25%    21940.750000
# 50%    27011.500000
# 75%    33431.250000
# max    72504.000000

# %%
bike_data.shape
# Out:
# (730, 10)

# %%
bike_data.head()
# Out:
#          date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0  04/01/2015              2.75              0.00     93.00    7.500000
# 1  05/01/2015              9.00              7.25     81.50    8.854167
# 2  06/01/2015              8.00              5.75     79.75   16.000000
# 3  07/01/2015              9.00              5.50     81.00   19.760870
# 4  08/01/2015              9.00              6.75     79.50   20.479167
#
#        weather_code  is_holiday  is_weekend  season  count
# 0     broken_clouds       False        True  winter   9234
# 1     broken_clouds       False       False  winter  20372
# 2             clear       False       False  winter  20613
# 3  scattered_clouds       False       False  winter  21064
# 4              rain       False       False  winter  15601

# %%
bike_data.tail()
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 725  30/12/2016              4.00              1.00     100.0    9.000000
# 726  31/12/2016              7.50              5.00      90.0   13.312500
# 727  01/01/2017              7.00              4.75      90.0   14.125000
# 728  02/01/2017              3.25              0.50      82.5   11.166667
# 729  03/01/2017              4.50              0.50      81.0   18.937500
#
#     weather_code  is_holiday  is_weekend  season  count
# 725       cloudy       False       False  winter  11566
# 726       cloudy       False        True  winter  11424
# 727         rain       False        True  winter   6421
# 728        clear        True       False  winter  11823
# 729        clear       False       False  winter  19436

# %%
bike_data.sample()
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 646  12/10/2016              12.0              12.0     80.75   13.666667
#
#          weather_code  is_holiday  is_weekend  season  count
# 646  scattered_clouds       False       False  autumm  32282

# %%
bike_data.sample(10)
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 337  07/12/2015             13.50             13.50     82.00   14.479167
# 92   06/04/2015              8.75              6.25     73.75   13.354167
# 435  14/03/2016              6.00               NaN     74.75   20.979167
# 429  08/03/2016              7.00              3.75     73.75   15.000000
# 709  14/12/2016             10.00              9.25     91.00    9.854167
# 566  23/07/2016             22.50             22.50     61.75    9.979167
# 348  18/12/2015             13.00             13.00     80.75   17.187500
# 298  29/10/2015             14.00             14.00     89.50   13.395833
# 712  17/12/2016              7.00              6.50     96.50    6.208333
# 227  19/08/2015             17.25             17.25     70.50   15.083333
#
#          weather_code  is_holiday  is_weekend  season  count
# 337               NaN       False       False  winter  25734
# ...

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
feel_temp = bike_data["feel_temperature"]
feel_temp
# Out:
# 0      0.00
# 1      7.25
# 2      5.75
# 3      5.50
# 4      6.75
#        ...
# 725    1.00
# 726    5.00
# 727    4.75
# 728    0.50
# 729    0.50
# Name: feel_temperature, Length: 730, dtype: float64

# %%
temp = bike_data[["real_temperature", "feel_temperature"]]
temp
# Out:
#      real_temperature  feel_temperature
# 0                2.75              0.00
# 1                9.00              7.25
# 2                8.00              5.75
# 3                9.00              5.50
# 4                9.00              6.75
# ..                ...               ...
# 725              4.00              1.00
# 726              7.50              5.00
# 727              7.00              4.75
# 728              3.25              0.50
# 729              4.50              0.50
#
# [730 rows x 2 columns]

# %%
# Make a copy of the df
toy_bikes = bike_data.copy()

# %%
toy_bikes.head()
# Out:
#          date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0  04/01/2015              2.75              0.00     93.00    7.500000
# 1  05/01/2015              9.00              7.25     81.50    8.854167
# 2  06/01/2015              8.00              5.75     79.75   16.000000
# 3  07/01/2015              9.00              5.50     81.00   19.760870
# 4  08/01/2015              9.00              6.75     79.50   20.479167
#
#        weather_code  is_holiday  is_weekend  season  count
# 0     broken_clouds       False        True  winter   9234
# 1     broken_clouds       False       False  winter  20372
# 2             clear       False       False  winter  20613
# 3  scattered_clouds       False       False  winter  21064
# 4              rain       False       False  winter  15601

# %%
toy_bikes.tail()
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 725  30/12/2016              4.00              1.00     100.0    9.000000
# 726  31/12/2016              7.50              5.00      90.0   13.312500
# 727  01/01/2017              7.00              4.75      90.0   14.125000
# 728  02/01/2017              3.25              0.50      82.5   11.166667
# 729  03/01/2017              4.50              0.50      81.0   18.937500
#
#     weather_code  is_holiday  is_weekend  season  count
# 725       cloudy       False       False  winter  11566
# 726       cloudy       False        True  winter  11424
# 727         rain       False        True  winter   6421
# 728        clear        True       False  winter  11823
# 729        clear       False       False  winter  19436

# %%
toy_bikes.sample(5)
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 606  01/09/2016             19.00             19.00     68.00   13.760870
# 672  07/11/2016              7.00              3.50     79.75   16.770833
# 696  01/12/2016              4.75              2.25     74.00   12.458333
# 587  13/08/2016             20.50             20.50     63.00   19.520833
# 113  27/04/2015              9.75               NaN     55.00   10.479167
#
#          weather_code  is_holiday  is_weekend  season  count
# 606             clear       False       False     NaN  39270
# 672  scattered_clouds       False       False  autumm  17193
# 696             clear       False       False     NaN  26245
# 587             clear       False        True     NaN  43041
# 113             clear       False       False  spring  30489

# %%
# Check number of missing entries per column
toy_bikes.isnull().sum()
# Out:
# date                 0
# real_temperature     0
# feel_temperature    73
# humidity             0
# wind_speed           0
# weather_code        51
# is_holiday           0
# is_weekend           0
# season              36
# count                0
# dtype: int64

# %%
# Drop missing entries 
toy_bikes.dropna()
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0    04/01/2015              2.75              0.00     93.00    7.500000
# 1    05/01/2015              9.00              7.25     81.50    8.854167
# 2    06/01/2015              8.00              5.75     79.75   16.000000
# 3    07/01/2015              9.00              5.50     81.00   19.760870
# 4    08/01/2015              9.00              6.75     79.50   20.479167
# ..          ...               ...               ...       ...         ...
# 725  30/12/2016              4.00              1.00    100.00    9.000000
# 726  31/12/2016              7.50              5.00     90.00   13.312500
# 727  01/01/2017              7.00              4.75     90.00   14.125000
# 728  02/01/2017              3.25              0.50     82.50   11.166667
# 729  03/01/2017              4.50              0.50     81.00   18.937500
#
#          weather_code  is_holiday  is_weekend  season  count
# ...

# %%
toy_bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
toy_bikes.isnull().sum()
# Out:
# date                 0
# real_temperature     0
# feel_temperature    73
# humidity             0
# wind_speed           0
# weather_code        51
# is_holiday           0
# is_weekend           0
# season              36
# count                0
# dtype: int64

# %%
# Drop missing values and write new df to file
toy_bikes.dropna(inplace=True)

# %%
toy_bikes.isnull().sum()
# Out:
# date                0
# real_temperature    0
# feel_temperature    0
# humidity            0
# wind_speed          0
# weather_code        0
# is_holiday          0
# is_weekend          0
# season              0
# count               0
# dtype: int64

# %%
toy_bikes.sample(10)
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 538  25/06/2016             16.00             16.00     77.00   13.562500
# 31   04/02/2015              3.00             -0.50     81.00   14.125000
# 559  16/07/2016             21.25             21.25     72.00   20.666667
# 244  05/09/2015             13.50             13.50     71.00   11.291667
# 224  16/08/2015             16.75             16.75     64.75    7.000000
# 657  23/10/2016             10.75             10.25     77.00   13.333333
# 115  29/04/2015              9.75              7.00     71.00   18.645833
# 690  25/11/2016              7.25              5.00     76.00   16.020833
# 529  16/06/2016             16.00             16.00     77.50   10.645833
# 308  08/11/2015             15.00             15.00     84.25   16.291667
#
#          weather_code  is_holiday  is_weekend  season  count
# 538              rain       False        True  summer  25939
# ...

# %%
toy_bikes.isnull()
# Out:
#       date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0    False             False             False     False       False
# 1    False             False             False     False       False
# 2    False             False             False     False       False
# 3    False             False             False     False       False
# 4    False             False             False     False       False
# ..     ...               ...               ...       ...         ...
# 725  False             False             False     False       False
# 726  False             False             False     False       False
# 727  False             False             False     False       False
# 728  False             False             False     False       False
# 729  False             False             False     False       False
#
#      weather_code  is_holiday  is_weekend  season  count
# 0           False       False       False   False  False
# ...

# %%
df = pd.DataFrame(dict(age=[5, 6, np.nan],
                       born=[pd.NaT, pd.Timestamp('1939-05-27'),
                             pd.Timestamp('1940-04-25')],
                       name=['Alfred', 'Batman', ''],
                       toy=[None, 'Batmobile', 'Joker']))

# %%
df
# Out:
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker

# %%
df.dropna()
# Out:
#    age       born    name        toy
# 1  6.0 1939-05-27  Batman  Batmobile

# %%
df
# Out:
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker

# %%
toy_bikes
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0    04/01/2015              2.75              0.00     93.00    7.500000
# 1    05/01/2015              9.00              7.25     81.50    8.854167
# 2    06/01/2015              8.00              5.75     79.75   16.000000
# 3    07/01/2015              9.00              5.50     81.00   19.760870
# 4    08/01/2015              9.00              6.75     79.50   20.479167
# ..          ...               ...               ...       ...         ...
# 725  30/12/2016              4.00              1.00    100.00    9.000000
# 726  31/12/2016              7.50              5.00     90.00   13.312500
# 727  01/01/2017              7.00              4.75     90.00   14.125000
# 728  02/01/2017              3.25              0.50     82.50   11.166667
# 729  03/01/2017              4.50              0.50     81.00   18.937500
#
#          weather_code  is_holiday  is_weekend  season  count
# ...

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              730 non-null    object
#  1   real_temperature  730 non-null    float64
#  2   feel_temperature  657 non-null    float64
#  3   humidity          730 non-null    float64
#  4   wind_speed        730 non-null    float64
#  5   weather_code      679 non-null    object
#  6   is_holiday        730 non-null    bool
#  7   is_weekend        730 non-null    bool
#  8   season            694 non-null    object
#  9   count             730 non-null    int64
# dtypes: bool(2), float64(4), int64(1), object(3)
# memory usage: 47.2+ KB

# %%
bikes_imputted = bike_data.copy()

# %%
bikes_imputted.head()
# Out:
#          date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0  04/01/2015              2.75              0.00     93.00    7.500000
# 1  05/01/2015              9.00              7.25     81.50    8.854167
# 2  06/01/2015              8.00              5.75     79.75   16.000000
# 3  07/01/2015              9.00              5.50     81.00   19.760870
# 4  08/01/2015              9.00              6.75     79.50   20.479167
#
#        weather_code  is_holiday  is_weekend  season  count
# 0     broken_clouds       False        True  winter   9234
# 1     broken_clouds       False       False  winter  20372
# 2             clear       False       False  winter  20613
# 3  scattered_clouds       False       False  winter  21064
# 4              rain       False       False  winter  15601

# %%
# Impute the missing data for feel_temperature

# Calculate the mean of the column
mean_feel_temperature = bikes_imputted["feel_temperature"].mean()


# Fill missing values
bikes_temp_imputted = bikes_imputted["feel_temperature"].fillna(mean_feel_temperature)
bikes_temp_imputted.sample(10)
# Out:
# 162    13.500000
# 548    11.506088
# 633    18.000000
# 59      4.000000
# 582    18.500000
# 678     7.500000
# 88      6.500000
# 165    18.250000
# 214    18.750000
# 194    20.500000
# Name: feel_temperature, dtype: float64

# %%
bikes_temp_imputted.isnull().sum()
# Out:
# 0

# %%
df
# Out:
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker

# %%
av_age = df["age"].mean()

df["filled_age"] = df["age"].fillna(av_age)
df
# Out:
#    age       born    name        toy  filled_age
# 0  5.0        NaT  Alfred       None         5.0
# 1  6.0 1939-05-27  Batman  Batmobile         6.0
# 2  NaN 1940-04-25              Joker         5.5

# %%
bikes_imputted["feel_temp_imputted"] = bikes_imputted["feel_temperature"].fillna(mean_feel_temperature)
bikes_imputted
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 0    04/01/2015              2.75              0.00     93.00    7.500000
# 1    05/01/2015              9.00              7.25     81.50    8.854167
# 2    06/01/2015              8.00              5.75     79.75   16.000000
# 3    07/01/2015              9.00              5.50     81.00   19.760870
# 4    08/01/2015              9.00              6.75     79.50   20.479167
# ..          ...               ...               ...       ...         ...
# 725  30/12/2016              4.00              1.00    100.00    9.000000
# 726  31/12/2016              7.50              5.00     90.00   13.312500
# 727  01/01/2017              7.00              4.75     90.00   14.125000
# 728  02/01/2017              3.25              0.50     82.50   11.166667
# 729  03/01/2017              4.50              0.50     81.00   18.937500
#
#          weather_code  is_holiday  is_weekend  season  count  \
# ...

# %%
bikes_imputted["avg_temp"] = (bikes_imputted["feel_temp_imputted"] + bikes_imputted["real_temperature"])/2

# %%
bikes_imputted.sample(5)
# Out:
#            date  real_temperature  feel_temperature  humidity  wind_speed  \
# 689  24/11/2016             10.00              7.75     77.00   22.104167
# 703  08/12/2016             13.00             13.00     82.00   16.312500
# 271  02/10/2015             13.00             13.00     77.00   10.729167
# 117  01/05/2015              9.00              6.00     63.00   18.875000
# 75   20/03/2015              6.25               NaN     79.75    9.854167
#
#          weather_code  is_holiday  is_weekend  season  count  \
# 689     broken_clouds       False       False  autumm  27941
# 703     broken_clouds       False       False  winter  28366
# 271             clear       False       False  autumm  35503
# 117  scattered_clouds       False       False  spring  29579
# 75              clear       False       False  spring  25226
#
#      feel_temp_imputted   avg_temp
# 689            7.750000   8.875000
# 703           13.000000  13.000000
# 271           13.000000  13.000000
# ...

# %%
bikes_imputted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                730 non-null    object
#  1   real_temperature    730 non-null    float64
#  2   feel_temperature    657 non-null    float64
#  3   humidity            730 non-null    float64
#  4   wind_speed          730 non-null    float64
#  5   weather_code        679 non-null    object
#  6   is_holiday          730 non-null    bool
#  7   is_weekend          730 non-null    bool
#  8   season              694 non-null    object
#  9   count               730 non-null    int64
#  10  feel_temp_imputted  730 non-null    float64
#  11  avg_temp            730 non-null    float64
# dtypes: bool(2), float64(6), int64(1), object(3)
# memory usage: 58.6+ KB

# %%
bikes_imputted.isnull().sum()
# Out:
# date                   0
# real_temperature       0
# feel_temperature      73
# humidity               0
# wind_speed             0
# weather_code          51
# is_holiday             0
# is_weekend             0
# season                36
# count                  0
# feel_temp_imputted     0
# avg_temp               0
# dtype: int64

# %%
# Fill missing values with the media value in the column
bikes_imputted["feel_temperature"] = bikes_imputted["feel_temperature"].fillna(bikes_imputted["feel_temperature"].median()
)

# %%
bikes_imputted.isnull().sum()
# Out:
# date                   0
# real_temperature       0
# feel_temperature       0
# humidity               0
# wind_speed             0
# weather_code          51
# is_holiday             0
# is_weekend             0
# season                36
# count                  0
# feel_temp_imputted     0
# avg_temp               0
# dtype: int64

# %%
# Fill missing values in season column using interpolation by padding
bikes_imputted['season'].interpolate(method='pad', inplace=True)
# Out:
# C:\Users\OneSud\AppData\Local\Temp\ipykernel_13000\3767119832.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   bikes_imputted['season'].interpolate(method='pad', inplace=True)
# C:\Users\OneSud\AppData\Local\Temp\ipykernel_13000\3767119832.py:2: FutureWarning: Series.interpolate with method=pad is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   bikes_imputted['season'].interpolate(method='pad', inplace=True)

# %%
bikes_imputted.isnull().sum()
# Out:
# date                   0
# real_temperature       0
# feel_temperature       0
# humidity               0
# wind_speed             0
# weather_code          51
# is_holiday             0
# is_weekend             0
# season                 0
# count                  0
# feel_temp_imputted     0
# avg_temp               0
# dtype: int64

# %%
bikes_imputted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                730 non-null    object
#  1   real_temperature    730 non-null    float64
#  2   feel_temperature    730 non-null    float64
#  3   humidity            730 non-null    float64
#  4   wind_speed          730 non-null    float64
#  5   weather_code        679 non-null    object
#  6   is_holiday          730 non-null    bool
#  7   is_weekend          730 non-null    bool
#  8   season              730 non-null    object
#  9   count               730 non-null    int64
#  10  feel_temp_imputted  730 non-null    float64
#  11  avg_temp            730 non-null    float64
# dtypes: bool(2), float64(6), int64(1), object(3)
# memory usage: 58.6+ KB

# %%
values_per_season = bikes_imputted["season"].value_counts()

# %%
values_per_season
# Out:
# season
# spring    185
# summer    184
# autumm    181
# winter    180
# Name: count, dtype: int64

# %% [markdown]
# # Merging and  Joining Data

# %%
# !pip install openpyxl
import pandas as pd

# Load the data
joining_data1 = pd.read_csv("../data/joining_data1.csv")
joining_data2 = pd.read_csv("../data/joining_data2.csv")
titanic = pd.read_excel("../data/titanic.xlsx")
union_data = pd.read_csv("../data/union_data.csv")
print(" Completed readinga and Importation of data ")
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#  Completed readinga and Importation of data

# %% [markdown]
# # Exploring Data

# %%
bike_data= pd.read_csv("../data/bikes.csv")
union_data= pd.read_csv("../data/union_data.csv")
join_data1= pd.read_csv("../data/joining_data1.csv")
join_data2= pd.read_csv("../data/joining_data2.csv")

print("Imported all data!")
# Out:
# Imported all data!

# %%
join_data1
# Out:
#                name animal  age
# 0   Catalie Portman    cat    3
# 1      Pico de Gato    cat    5
# 2         Chewbarka    dog    1
# 3  Sir Isaac Mewton    cat    7
# 4                K9    cat   11
# 5         Arf Vader    dog    6

# %%
join_data2
# Out:
#                name  vaccinated
# 0   Catalie Portman        True
# 1      Pico de Gato        True
# 2         Chewbarka       False
# 3  Sir Isaac Mewton        True
# 4                K9       False
# 5         Spiderpig        True

# %%
# Performing Data Joins

# %%
# Left Joins

# %%
join_data = pd.merge (left=join_data1, right= join_data2, how='left', on = 'name')

# %%
join_data
# Out:
#                name animal  age vaccinated
# 0   Catalie Portman    cat    3       True
# 1      Pico de Gato    cat    5       True
# 2         Chewbarka    dog    1      False
# 3  Sir Isaac Mewton    cat    7       True
# 4                K9    cat   11      False
# 5         Arf Vader    dog    6        NaN

# %%
# Right JOIN

# %%
right_join_data = pd.merge (left=join_data1, right= join_data2, how='right', on = 'name')

# %%
right_join_data
# Out:
#                name animal   age  vaccinated
# 0   Catalie Portman    cat   3.0        True
# 1      Pico de Gato    cat   5.0        True
# 2         Chewbarka    dog   1.0       False
# 3  Sir Isaac Mewton    cat   7.0        True
# 4                K9    cat  11.0       False
# 5         Spiderpig    NaN   NaN        True

# %% [markdown]
# # Outer Join

# %% [markdown]
# # Inner Join

# %% [markdown]
# # Aggregation

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  home.dest  745 non-null    object
#  12  body       121 non-null    float64
#  13  boat       486 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'home.dest', 'body', 'boat'],
#       dtype='object')

# %%
# Count Passengers by  sex
titanic ["sex"].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
#Check survival by sex -> using the group by method 

titanic.groupby("sex")["survived"].sum()
# Out:
# sex
# female    339
# male      161
# Name: survived, dtype: int64

# %%
#Check survival by sex -> using the group by method 

titanic.groupby("sex")["survived"].agg(["sum", "mean"])
# Out:
#         sum      mean
# sex
# female  339  0.727468
# male    161  0.190985

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'home.dest', 'body', 'boat'],
#       dtype='object')

# %%
# Home Work  

# 1.Does the ticket fare(fare),  passsenger class  (pclass), family  members (parch)  affect the chances of survival?


#  Get the percentage, avg cost of a ticket based on embarkment

# Check the survival by sex 

# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()


# Create a visualization
sns.relplot(
    data=titanic,
    x="fare", y="pclass",  size="parch",sizes =(250,300))

# %% [markdown]
# # Pivot Tables

# %%
titanic_pivot = titanic.pivot_table(values="fare",index="sex",aggfunc="mean")

titanic_pivot
# Out:
#              fare
# sex
# female  46.198097
# male    26.154601

# %%
titanic_data_copy=titanic.copy()

titanic_data_copy
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
# Renaming columns in your data set

titanic_data_copy.rename (columns={'sex':'gender'},  inplace=True)

titanic_data_copy
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender      age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
# capitalizing values 

titanic_data_copy.columns= titanic_data_copy.columns.str.capitalize()

titanic_data_copy.columns
# Out:
# Index(['Pclass', 'Survived', 'Name', 'Gender', 'Age', 'Sibsp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Home.dest', 'Body', 'Boat'],
#       dtype='object')

# %%
# Observation

# %%
# lookup using labels 

print(titanic_data_copy.loc[1:11, ['Cabin','Fare']])

# titanic_data_copy
# Out:
#       Cabin      Fare
# 1   C22 C26  151.5500
# 2   C22 C26  151.5500
# 3   C22 C26  151.5500
# 4   C22 C26  151.5500
# 5       E12   26.5500
# 6        D7   77.9583
# 7       A36    0.0000
# 8      C101   51.4792
# 9       NaN   49.5042
# 10  C62 C64  227.5250
# 11  C62 C64  227.5250

# %%
# lookup using indexes(getting the row  values )


# getting the values from the first and third rows and from the 2nd and 4th columns
titanic_data_copy.iloc[[0,2],[1,3]]
# Out:
#    Survived  Gender
# 0         1  female
# 2         0  female

# %%
titanic_data_copy.iloc[:10,[0,2,5,6]]
# Out:
#    Pclass                                             Name  Sibsp  Parch
# 0       1                    Allen, Miss. Elisabeth Walton      0      0
# 1       1                   Allison, Master. Hudson Trevor      1      2
# 2       1                     Allison, Miss. Helen Loraine      1      2
# 3       1             Allison, Mr. Hudson Joshua Creighton      1      2
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      1      2
# 5       1                              Anderson, Mr. Harry      0      0
# 6       1                Andrews, Miss. Kornelia Theodosia      1      0
# 7       1                           Andrews, Mr. Thomas Jr      0      0
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)      2      0
# 9       1                          Artagaveytia, Mr. Ramon      0      0

# %%
# Data sorting

# %%
titanic_data_copy.sort_values(by= 'Pclass',ascending=False)
# Out:
#      Pclass  Survived                            Name  Gender   Age  Sibsp  \
# 654       3         0             Baccos, Mr. Raffull    male  20.0      0
# 860       3         1          Heikkinen, Miss. Laina  female  26.0      0
# 878       3         0   Ilmakangas, Miss. Pieta Sofia  female  25.0      1
# 877       3         0    Ilmakangas, Miss. Ida Livija  female  27.0      1
# 876       3         0                Ilieff, Mr. Ylio    male   NaN      0
# ..      ...       ...                             ...     ...   ...    ...
# 218       1         1    Oliva y Ocana, Dona. Fermina  female  39.0      0
# 219       1         1       Omont, Mr. Alfred Fernand    male   NaN      0
# 220       1         1    Ostby, Miss. Helene Ragnhild  female  22.0      0
# 221       1         0  Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 0         1         1   Allen, Miss. Elisabeth Walton  female  29.0      0
#
# ...

# %%
sns.countplot(x="Survived", 
              data= titanic_data_copy,
              hue= "Gender",
              palette= ["blue","green"]
             )
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# plotting the Fare Distributions  
# sns.pal
sns.displot(data=titanic_data_copy, x="Fare", hue="Gender",  binwidth=50)

# %%
# Interpreting the data using box plots

sns.boxplot(x="Pclass",  y='Age',hue= "Gender", data= titanic_data_copy)
plt.title("Age Distribution by Class")
# Out:
# Text(0.5, 1.0, 'Age Distribution by Class')

# %%
sns.heatmap(titanic_data_copy.isnull(),cbar=False,cmap="viridis")
plt.title("Passenger Gender Distribution")
# Out:
# Text(0.5, 1.0, 'Passenger Gender Distribution')
